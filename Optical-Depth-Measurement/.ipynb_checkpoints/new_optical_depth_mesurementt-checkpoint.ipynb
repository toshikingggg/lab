# %%
import math
import numpy as np

#解の公式
def quadratic_formula(a,b,r,x):
    if a==1 or a==-1:
        print("解の公式が適応できません")
        return 0
    else:
        #判別式で直線と交わっているか確かめる
        D = pow(a,2)*pow(b,2)-(1+pow(a,2))*(pow(b,2)-pow(r,2))
        if D<0:
            print("光線が内周の円と交わっていません")
            return 0
        elif D == 0:
            print("直線と円が接しています")
        else:
            if x<0:
                return (-a*b-math.sqrt(pow(a,2)*pow(b,2)-(1+pow(a,2))*(pow(b,2)-pow(r,2))))/(1+pow(a,2))
            elif x==0:
                return x
            elif x>0:
                return (-a*b+math.sqrt(pow(a,2)*pow(b,2)-(1+pow(a,2))*(pow(b,2)-pow(r,2))))/(1+pow(a,2))

            
#直線の傾き
def katamuki(n_i ,n_r ,x_i,y_i,sita_h_i,sita_r_i,sita_i,sin_i):
    if n_i>n_r:
        sin_c = n_r/n_i
        sita_c = math.asin(sin_c)
        if sita_c > sita_i:
            #屈折しつつ透過
            #屈折角を求める
            sin_r = n_i*sin_i/n_r
            sita_r = math.asin(sin_r)
            print("ここコードなくね????")
            #同じものでよさそう
            if x_i<0:
                if y_i>0:
                    gradient_i = math.tan(-(sita_h_i+sita_r))
                    return gradient_i
                if y_i<0:
                    gradient_i = math.tan(-(math.radians(180)-(sita_h_i+sita_r)))
                    return gradient_i
            elif x_i ==0:
                print("x_i=0")
            elif x_i>0:
                if y_i>0:
                    gradient_i = math.tan(-(math.radians(180)-(sita_h_i+sita_r)))
                    return gradient_i
                if y_i<0:
                    gradient_i = math.tan(-(sita_h_i+sita_r))
                    return gradient_i
            
        else:
            #全反射
            sita_r = sita_i
            
            if x_i<0:
                gradient_i = math.tan(-(math.radians(180)-(sita_r-sita_h_i)))
                return gradient_i
            elif x_i==0:
                print("おそらく存在しない")
            elif x_i>0:
                gradient_i = math.tan(-(sita_r-sita_h_i))
                return gradient_i
    else:
        if x_i<0:
            if y_i>0:
                gradient_i = math.tan(-(sita_h_i+sita_r_i))
                return gradient_i
            if y_i<0:
                gradient_i = math.tan(-(math.radians(180)-(sita_h_i+sita_r_i)))
                return gradient_i
        elif x_i ==0:
            print("x_i=0")
        elif x_i>0:
            if y_i>0:
                gradient_i = math.tan(-(math.radians(180)-(sita_h_i+sita_r_i)))
                return gradient_i
            if y_i<0:
                gradient_i = math.tan(-(sita_h_i+sita_r_i))
                return gradient_i

            
#角計測部分
#全反射0 その他１
def calculate_angle_and_(n_i ,n_r ,x ,y ,x_i ,y_i, r_i,change):
    #求めたい角度に必要な2つの直線
    #1.y軸に平行な直線の式はx=h → 0*y+1*x-h=0
    a = -(y_i - y)
    b = x_i - x
    #2.接線に垂直な直線→便利な公式：ax+by+c=0 に垂直で，(x0,y0) を通る直線の方程式は，b(x−x0)−a(y−y0)=0
    c = y_i
    d = -x_i
    if a*c + b*d == 0:
        print("a*c + b*d",a*c + b*d)
        return 0,0
    #2直線の成す角→入射角
    tan = (abs(a*d - b*c))/(abs(a*c + b*d))
    sita_i = math.atan(tan)
    #スネルの法則にひつような入射角のsin
    sin_i = math.sin(sita_i)
    
    sita_h_i = math.atan(tan)
    sin_h_i = math.sin(sita_h_i)
#     print("n_i",n_i)
#     print("n_r",n_r)
#     print("sin_i",sin_i)
    if change == 0:
        sita_r = sita_i
        print("calcの中、全反射だよ")
    else:
        sin_r = n_i*sin_i/n_r
        if sin_r > 1:
            print("sinが1を超えてる")
            return 0,0
        sita_r = math.asin(sin_r)
    
    gradient_i = katamuki(n_i ,n_r ,x_i,y_i,sita_h_i,sita_r,sita_i,sin_i) 
    print("gradient_i",gradient_i)
    if gradient_i == None:
        print("てすと")
        return 0,0
    y_intercept_i = y_i - gradient_i * x_i
    x_i_i = quadratic_formula(gradient_i,y_intercept_i,r_i,x_i)
    y_i_i = gradient_i*x_i_i + y_intercept_i
    return x_i_i ,y_i_i


    
#外周の半径を定義
r = int(input("外径の半径を入力(mm)"))
r_i  = int(input("内径の半径を入力(mm)"))
r_h = int(input("光を受け取る位置を入力(mm)(外径の半径よりも大きくすること)"))

xlist = []
ylist = []
cnt=0


for x in range(-r+1,r):
    if x == 0:
        continue
    print("x",x)
    #最初
    y = 0
    x_i = x
    y_i = math.sqrt(pow(r,2)-pow(x_i,2))
    
    n_i = 1.000292
    n_r = 1.49
    #2つ目の座標
    #ここで内径に接しない場合も考える必要がある。
    x_i_i, y_i_i = calculate_angle_and_(n_i ,n_r ,x ,y ,x_i ,y_i, r_i,1)
    print("1回目のcalc")
    if x_i_i == 0 and y_i_i == 0:
        print("--------------------------------------")
        cnt +=1
        continue
    #内側→外
    n_i = 1.49
    n_r = 1.000292
    sin_c = n_r/n_i
    sita_c = math.asin(sin_c)    
    a = -(y_i_i - y_i)
    b = x_i_i - x_i
    c = y_i_i
    d = -x_i_i
    
    tan = (abs(a*d - b*c))/(abs(a*c + b*d))
    sita_i = math.atan(tan)
    #3つ目の座標 透過or全反射→どう分けよう とりあえずaをトリガーにする？→aと半径をトリガーにする？
    #ここのrが問題→全反射と内部を透過する場合で代入しなければならない半径が異なる
    if sita_c > sita_i:
        x_i_i_i, y_i_i_i = calculate_angle_and_(n_i ,n_r ,x_i ,y_i ,x_i_i ,y_i_i, r_i,1)
        print("2回目のcalc　内部")
        if x_i_i_i == 0 and y_i_i_i == 0:
            print("--------------------------------------")
            cnt +=1
            continue
        n_i = 1.000292
        n_r = 1.49 
        x_i_i_r, y_i_i_r = calculate_angle_and_(n_i ,n_r ,x_i_i ,y_i_i ,x_i_i_i ,y_i_i_i, r,1)
        print("3回目のcalc")
        if x_i_i_r == 0 and y_i_i_r == 0:
            print("--------------------------------------")
            cnt +=1
            continue
        n_i = 1.49
        n_r = 1.000292
        x_get,y_get = calculate_angle_and_(n_i ,n_r ,x_i_i_i ,y_i_i_i ,x_i_i_r ,y_i_i_r, r_h,1)
        print("最後のcalc　内部透過")
        print("--------------------------------------")
    elif sita_c < sita_i:      
        print("全反射ルート")
        x_i_i_r, y_i_i_r = calculate_angle_and_(n_i ,n_r ,x_i ,y_i ,x_i_i ,y_i_i, r,0)
        print("2回目のcalc 全反射")
        if x_i_i_r == 0 and y_i_i_r == 0:
            print("--------------------------------------")
            cnt +=1
            continue
        x_get,y_get = calculate_angle_and_(n_i ,n_r ,x_i_i ,y_i_i ,x_i_i_r ,y_i_i_r, r_h,1)
        print("最後のcalc　全反射")
        print("--------------------------------------")
    if 0<=y_get:
        continue
    xlist.append(x_get)
    ylist.append(y_get)
# Out:
# 外径の半径を入力(mm) 1000
# 内径の半径を入力(mm) 920
# 光を受け取る位置を入力(mm)(外径の半径よりも大きくすること) 1300
# x -999
# gradient_i 1.2106886180215353
# 1回目のcalc
# 全反射ルート
# calcの中、全反射だよ
# gradient_i 1.2246467991473532e-16
# 2回目のcalc 全反射
# ここコードなくね????
# gradient_i -0.41422861373473924
# 最後のcalc　全反射
# --------------------------------------
# x -998
# gradient_i 1.2597737094797277
# 1回目のcalc
# 全反射ルート
# calcの中、全反射だよ
# gradient_i 1.2246467991473532e-16
# 2回目のcalc 全反射
# ここコードなくね????
# gradient_i -0.502662532303703
# 最後のcalc　全反射
# --------------------------------------
# x -997
# gradient_i 1.2996707852144012
# 1回目のcalc
# 全反射ルート
# calcの中、全反射だよ
# gradient_i 1.2246467991473532e-16
# 2回目のcalc 全反射
# ここコードなくね????
# gradient_i -0.5807731291400366
# 最後のcalc　全反射
# --------------------------------------
# x -996
# gradient_i 1.334945162470192
# 1回目のcalc
# 全反射ルート
# calcの中、全反射だよ
# gradient_i 1.2246467991473532e-16
# 2回目のcalc 全反射
# ここコードなくね????
# gradient_i -0.6565915663849415
# 最後のcalc　全反射
# --------------------------------------
# ...

# %%
#全反射していないときの受光状態 幅は持たせていない
import matplotlib.pyplot as plt
import matplotlib.patches as patches



g = plt.subplot()
#外径
draw_circle_r = plt.Circle((0, 0), r, fill=False)
#内径
draw_circle_i = plt.Circle((0, 0), r_i, fill=False)
g.add_artist(draw_circle_r)
g.add_artist(draw_circle_i)
g.plot(xlist, ylist, marker="o", color = "red", linestyle = " ",markersize=1)
g.set_aspect('equal')

print("取得できていない座標の数",cnt)
# Out:
# 取得できていない座標の数 735

# %%
#大きさが知りたい
#幅をもたせるやり方→おかしいかも
new_X_list = []
L_list = []
# xlist = [1001.5,1001.4,1002.3,1000.6,1000.1,1007]
test = []
ans_x = []
for i in xlist:
    keepplus = i + 1
    keepminus = i - 1
    hikaku = round(keepplus)
#     print("keepplus",keepplus)
#     print("hikaku",i)
    #大きさ プラス側にいれる大きさ
    intensity_plus = keepplus-int(keepplus)
    new_X_list.append(int(keepplus))
    L_list.append(intensity_plus)
    intensity_minus = int(i)-keepminus
    new_X_list.append(int(keepminus))
    L_list.append(intensity_minus)

# print("X座標",new_X_list)
# print("光の大きさ",L_list)


#同じ座標における光の大きさを足し合わせてグラフに描画したい
for i in range(len(new_X_list)):
    test.append(L_list[i])
    l=0
    j = i+1
    if set(ans_x) <= set(new_X_list) == True:
        #ほしい座標の大きさはすでに計算済み
        continue
    else:
        while j < len(new_X_list):
            if new_X_list[i] == new_X_list[j]:
                test[i] += L_list[j]
            j +=1
        ans_x.append(new_X_list[i])

for i in range(len(ans_x)):
    #print(i,"回目のans_x内",ans_x)
    for j in reversed(range(i+1,len(ans_x))):
        if ans_x[i] == ans_x[j]:
            del ans_x[j]
            del test[j]
            #print("ifの中")
    
# print("ほしいX座標",ans_x)
# print("光の大きさ",test)

plt.bar(ans_x, test, width=1.0)
# Out:
# <BarContainer object of 574 artists>
